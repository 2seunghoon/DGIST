# %%
# %cd /home/cvintern2/Desktop/intern/OWDA
# Out:
# /home/cvintern2/Desktop/intern/OWDA

# %%
import random
import torch
import cv2
import numpy as np

# %%
img1=cv2.imread('image1.jpg')
origin=cv2.imread('origin.jpg')

origin=cv2.cvtColor(origin,cv2.COLOR_BGR2RGB)

# %%
origin.shape
# Out:
# (1046, 1914, 3)

# %%
# origin=origin.transpose(2,1,0)
type(origin)
# origin.shape
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.imshow(origin)
plt.show()

# %%
from albumentations.augmentations.transforms import ColorJitter
# from torchvision.transforms import ColorJitter

# %%
type(origin)
# kk=torch.Tensor(origin.reshape(3,1046,1914))
# type(kk)
# Out:
# torch.Tensor

# %%
print(origin.shape)
type(origin)
# Out:
# (1046, 1914, 3)
# numpy.ndarray

# %%
cj=ColorJitter(brightness=0.5,contrast=0.5,saturation=0.5,hue=0.5)
# cj=ColorJitter(hue=0.5)

test1=cj(image=origin)

# %%
test1['image'].shape
# test1['image'].shape
# Out:
# (1046, 1914, 3)

# %%
# plt.imshow(test1.reshape(1046,1914,3))
plt.imshow(test1['image'])
plt.show()

# %%
test=cj(image=origin)
plt.imshow(test['image'])

# %%
test1['image']
# Out:
# array([[[ 49,  47,  50],
#         [ 73,  73,  75],
#         [ 53,  52,  58],
#         ...,
#         [244, 239, 233],
#         [244, 239, 233],
#         [244, 239, 233]],
#
#        [[ 61,  59,  62],
#         [ 59,  59,  61],
#         [ 55,  56,  60],
#         ...,
#         [244, 239, 233],
#         [244, 239, 233],
#         [244, 239, 233]],
#
#        [[ 50,  50,  52],
#         [ 73,  73,  75],
#         [ 57,  58,  62],
#         ...,
#         [244, 239, 233],
#         [245, 240, 234],
#         [245, 240, 234]],
#
#        ...,
#
#        [[130, 125, 103],
#         [131, 126, 104],
#         [131, 126, 104],
#         ...,
#         [ 38,  49,  69],
#         [ 38,  49,  69],
#         [ 38,  49,  69]],
#
#        [[125, 120,  98],
#         [127, 122, 100],
#         [130, 125, 103],
#         ...,
#         [ 38,  49,  69],
#         [ 38,  49,  69],
#         [ 38,  49,  69]],
#
#        [[133, 128, 106],
#         [137, 132, 110],
#         [142, 137, 115],
# ...

# %%
test['image']
# Out:
# array([[[ 49,  47,  50],
#         [ 73,  73,  75],
#         [ 53,  52,  58],
#         ...,
#         [244, 239, 233],
#         [244, 239, 233],
#         [244, 239, 233]],
#
#        [[ 61,  59,  62],
#         [ 59,  59,  61],
#         [ 55,  56,  60],
#         ...,
#         [244, 239, 233],
#         [244, 239, 233],
#         [244, 239, 233]],
#
#        [[ 50,  50,  52],
#         [ 73,  73,  75],
#         [ 57,  58,  62],
#         ...,
#         [244, 239, 233],
#         [245, 240, 234],
#         [245, 240, 234]],
#
#        ...,
#
#        [[130, 125, 103],
#         [131, 126, 104],
#         [131, 126, 104],
#         ...,
#         [ 38,  49,  69],
#         [ 38,  49,  69],
#         [ 38,  49,  69]],
#
#        [[125, 120,  98],
#         [127, 122, 100],
#         [130, 125, 103],
#         ...,
#         [ 38,  49,  69],
#         [ 38,  49,  69],
#         [ 38,  49,  69]],
#
#        [[133, 128, 106],
#         [137, 132, 110],
#         [142, 137, 115],
# ...
